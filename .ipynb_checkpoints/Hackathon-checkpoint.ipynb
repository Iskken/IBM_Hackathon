# %% [markdown]
# # Solution Implementation

# %% [markdown]
# ## Libraries

# %%
from __future__ import annotations

import random
from dataclasses import dataclass
from typing import Tuple

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from math import log2, floor

from qiskit import QuantumCircuit, ClassicalRegister, QuantumRegister
from qiskit_aer import AerSimulator
from qiskit_aer.noise import NoiseModel, depolarizing_error

# %% [markdown]
# ## Config Constants

# %%
# -------------------- Config --------------------
N_BITS = 1024
SAMPLE_FRACTION = 0.15           # fraction of sifted bits publicly revealed for QBER estimation
SEED = 2025
NOISE_LEVELS = [0.0, 0.01, 0.02, 0.05, 0.10, 0.20]  # depolarizing probabilities to sweep
F_EC = 1.16                      # error-correction inefficiency >= 1
OUT_CSV = "bb84_metrics_qiskit_secure.csv"

# %% [markdown]
# ## Helper Functions

# %%
def h2(x: float) -> float:
    if x <= 0.0 or x >= 1.0:
        return 0.0
    return -x*log2(x) - (1-x)*log2(1-x)


def generate_random_bits_and_bases(n: int, rng: random.Random):
    alice_bits = np.array([rng.randint(0, 1) for _ in range(n)], dtype=int)
    alice_bases = np.array([rng.randint(0, 1) for _ in range(n)], dtype=int)  # 0=+, 1=×
    bob_bases = np.array([rng.randint(0, 1) for _ in range(n)], dtype=int)
    return alice_bits, alice_bases, bob_bases

# %% [markdown]
# ## Circuit Building

# %%
def build_bb84_circuit(alice_bits: np.ndarray, alice_bases: np.ndarray, bob_bases: np.ndarray, noise_p: float):
    n = len(alice_bits)
    q = QuantumRegister(n, "q")
    c = ClassicalRegister(n, "c")
    qc = QuantumCircuit(q, c)

    for i in range(n):
        if alice_bits[i] == 1:
            qc.x(q[i])
        if alice_bases[i] == 1:         # encode in diagonal basis
            qc.h(q[i])

        # "Channel" (placeholder) – attach noise to this id gate via NoiseModel
        qc.id(q[i])

        # Bob's measurement basis
        if bob_bases[i] == 1:           # measure in diagonal via H then Z
            qc.h(q[i])

        qc.measure(q[i], c[i])

    # Noise model: depolarizing on 'id'
    noise_model = NoiseModel()
    if noise_p > 0:
        noise_model.add_all_qubit_quantum_error(depolarizing_error(noise_p, 1), ["id"])
    return qc, noise_model

# %% [markdown]
# ## Run BB84 Circuit

# %%
def run_once_with_aer(n_bits: int, noise_p: float, seed: int):
    rng = random.Random(seed)
    alice_bits, alice_bases, bob_bases = generate_random_bits_and_bases(n_bits, rng)
    qc, noise_model = build_bb84_circuit(alice_bits, alice_bases, bob_bases, noise_p)

    sim = AerSimulator(seed_simulator=seed)
    result = sim.run(qc, shots=1, noise_model=noise_model).result()
    counts = result.get_counts()
    bitstring = next(iter(counts.keys()))[::-1]  # reverse to align index i->position i
    bob_bits = np.array(list(bitstring), dtype=int)
    return alice_bits, alice_bases, bob_bases, bob_bits

# %% [markdown]
# ## QBER Estimation and Sift dataclass

# %%
@dataclass
class SiftResult:
    sift_idx: np.ndarray
    sample_idx: np.ndarray
    alice_sift: np.ndarray
    bob_sift: np.ndarray
    sifted_len: int
    sample_size: int
    qber_estimate: float | None
    final_key_alice: np.ndarray
    final_key_bob: np.ndarray


def sift_and_estimate_qber(alice_bits, alice_bases, bob_bases, bob_bits,
                           sample_fraction=0.15, seed=0) -> SiftResult:
    rng = random.Random(seed)
    match_mask = (alice_bases == bob_bases)
    sift_idx = np.where(match_mask)[0]
    alice_sift = alice_bits[sift_idx]
    bob_sift = bob_bits[sift_idx]
    sifted_len = len(alice_sift)

    if sifted_len == 0:
        return SiftResult(
            sift_idx=sift_idx, sample_idx=np.array([], dtype=int), alice_sift=alice_sift, bob_sift=bob_sift,
            sifted_len=0, sample_size=0, qber_estimate=None,
            final_key_alice=np.array([], dtype=int), final_key_bob=np.array([], dtype=int)
        )

    sample_size = max(1, int(round(sample_fraction * sifted_len)))
    sample_idx = np.array(rng.sample(list(range(sifted_len)), sample_size), dtype=int)

    errors = int(np.sum(alice_sift[sample_idx] != bob_sift[sample_idx]))
    qber = errors / sample_size

    keep_mask = np.ones(sifted_len, dtype=bool)
    keep_mask[sample_idx] = False
    final_key_alice = alice_sift[keep_mask]
    final_key_bob = bob_sift[keep_mask]

    return SiftResult(sift_idx, sample_idx, alice_sift, bob_sift, sifted_len, sample_size, qber,
                      final_key_alice, final_key_bob)

# %% [markdown]
# ## Main Experiment

# %%
# -------------------- Main experiment --------------------
def main():
    rows = []

    for i, p in enumerate(NOISE_LEVELS):
        # Use different seeds per noise for independence (optional)
        seed_i = SEED + i

        alice_bits, alice_bases, bob_bases, bob_bits = run_once_with_aer(N_BITS, p, seed=seed_i)
        sift = sift_and_estimate_qber(alice_bits, alice_bases, bob_bases, bob_bits,
                                      sample_fraction=SAMPLE_FRACTION, seed=seed_i)

        kept_after_sampling = sift.sifted_len - sift.sample_size

        # Asymptotic secret fraction per kept bit: R(q) = 1 - f_EC h(q) - h(q)
        if sift.qber_estimate is None:
            usable_fraction = 0.0
        else:
            usable_fraction = max(0.0, 1.0 - F_EC*h2(sift.qber_estimate) - h2(sift.qber_estimate))

        final_secure_len = floor(kept_after_sampling * usable_fraction)

        rows.append({
            "noise_p": p,
            "n_sent": N_BITS,
            "n_sifted": sift.sifted_len,
            "sifted_fraction": sift.sifted_len / N_BITS if N_BITS else 0.0,
            "sample_size": sift.sample_size,
            "qber_estimate": sift.qber_estimate,
            "final_key_len": kept_after_sampling,     # raw after sampling (for reference)
            "final_secure_len": final_secure_len      # <-- LAST COLUMN (usable key after EC+PA)
        })

    df = pd.DataFrame(rows)
    print("\n=== BB84 metrics (Qiskit Aer) ===")
    print(df.to_string(index=False))

    # Save CSV
    df.to_csv(OUT_CSV, index=False)
    print(f"\nSaved metrics CSV to: {OUT_CSV}")

    # Plot secure key vs noise
    plt.figure()
    plt.plot(df["noise_p"], df["final_secure_len"], marker="o")
    plt.title("Final Secure Key Size vs Depolarizing Noise (Qiskit Aer, asymptotic post-processing)")
    plt.xlabel("Depolarizing probability (noise_p)")
    plt.ylabel("Final secure key size (bits)")
    plt.grid(True)
    plt.tight_layout()
    plt.savefig("final_secure_key_vs_noise.png", dpi=160)
    print("Saved: final_secure_key_vs_noise.png")

# %%
# -------------------- Main experiment --------------------
def main():
    rows = []

    for i, p in enumerate(NOISE_LEVELS):
        # Use different seeds per noise for independence (optional)
        seed_i = SEED + i

        alice_bits, alice_bases, bob_bases, bob_bits = run_once_with_aer(N_BITS, p, seed=seed_i)
        sift = sift_and_estimate_qber(alice_bits, alice_bases, bob_bases, bob_bits,
                                      sample_fraction=SAMPLE_FRACTION, seed=seed_i)

        kept_after_sampling = sift.sifted_len - sift.sample_size

        # Asymptotic secret fraction per kept bit: R(q) = 1 - f_EC h(q) - h(q)
        if sift.qber_estimate is None:
            usable_fraction = 0.0
        else:
            usable_fraction = max(0.0, 1.0 - F_EC*h2(sift.qber_estimate) - h2(sift.qber_estimate))

        final_secure_len = floor(kept_after_sampling * usable_fraction)

        rows.append({
            "noise_p": p,
            "n_sent": N_BITS,
            "n_sifted": sift.sifted_len,
            "sifted_fraction": sift.sifted_len / N_BITS if N_BITS else 0.0,
            "sample_size": sift.sample_size,
            "qber_estimate": sift.qber_estimate,
            "final_key_len": kept_after_sampling,     # raw after sampling (for reference)
            "final_secure_len": final_secure_len      # <-- LAST COLUMN (usable key after EC+PA)
        })

    df = pd.DataFrame(rows)
    print("\n=== BB84 metrics (Qiskit Aer) ===")
    print(df.to_string(index=False))

    # Save CSV
    # df.to_csv(OUT_CSV, index=False)
    # print(f"\nSaved metrics CSV to: {OUT_CSV}")

    # Plot secure key vs noise
    plt.figure()
    plt.plot(df["noise_p"], df["final_secure_len"], marker="o")
    plt.title("Final Secure Key Size vs Depolarizing Noise (Qiskit Aer, asymptotic post-processing)")
    plt.xlabel("Depolarizing probability (noise_p)")
    plt.ylabel("Final secure key size (bits)")
    plt.grid(True)
    plt.tight_layout()
    plt.savefig("final_secure_key_vs_noise.png", dpi=160)
    print("Saved: final_secure_key_vs_noise.png")

# %% [markdown]
# ***
# Running
# ***

# %%
if __name__ == "__main__":
    main()
# Out:
# === BB84 metrics (Qiskit Aer) ===
#  noise_p  n_sent  n_sifted  sifted_fraction  sample_size  qber_estimate  final_key_len  final_secure_len
#     0.00    1024       499         0.487305           75       0.000000            424               424
#     0.01    1024       527         0.514648           79       0.012658            448               353
#     0.02    1024       513         0.500977           77       0.025974            436               272
#     0.05    1024       511         0.499023           77       0.064935            434               108
#     0.10    1024       487         0.475586           73       0.041096            414               192
#     0.20    1024       537         0.524414           81       0.123457            456                 0
#
# Saved metrics CSV to: bb84_metrics_qiskit_secure.csv
# Saved: final_secure_key_vs_noise.png

# %% [markdown]
# ![image.png](attachment:17d3ce3d-6523-47ca-9e72-a70ee02a6350.png)
